# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sys
import os
sys.path.append('lib/')
import freqtrade_support as fs

# %%
DATA_DIR = 'ft_userdata/user_data/data'
os.listdir(DATA_DIR)
# Out:
# ['kraken', 'binance']

# %%
js_path = os.path.join(DATA_DIR, 'kraken', 'ETH_BTC-1h.json')

# %%
candles = fs.Candles(js_path)

# %%
candles.plot()

# %%
candles.df
# Out:
#                 ds        O        H        L        C           V
# 0    1649613600000  0.07646  0.07659  0.07626  0.07628   13.411084
# 1    1649617200000  0.07630  0.07633  0.07616  0.07618   50.102133
# 2    1649620800000  0.07618  0.07634  0.07592  0.07630   65.603722
# 3    1649624400000  0.07631  0.07655  0.07612  0.07653   65.119222
# 4    1649628000000  0.07655  0.07675  0.07620  0.07655   54.091712
# ..             ...      ...      ...      ...      ...         ...
# 714  1652184000000  0.07597  0.07601  0.07578  0.07599  249.869104
# 715  1652187600000  0.07600  0.07618  0.07578  0.07615  300.789548
# 716  1652191200000  0.07616  0.07623  0.07582  0.07587  273.899048
# 717  1652194800000  0.07588  0.07590  0.07516  0.07544  354.066890
# 718  1652198400000  0.07543  0.07558  0.07515  0.07535  276.141175
#
# [719 rows x 6 columns]

# %%
pd.to_datetime(candles.df['ds'],unit='ms').iloc[0]
# Out:
# Timestamp('2022-04-10 18:00:00')
